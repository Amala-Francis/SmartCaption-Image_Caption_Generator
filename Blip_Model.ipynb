# %%
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
# Out:
# WARNING:tensorflow:From C:\Users\ACER\OneDrive\Desktop\SmartCaption\myenv310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\ACER\OneDrive\Desktop\SmartCaption\myenv310\lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
image = Image.open("C:\\Users\\ACER\\OneDrive\\Desktop\\SmartCaption\\flickr30k\\574181.jpg").convert("RGB")
inputs = processor(image, return_tensors="pt")

# %%
with torch.no_grad():  # No gradient calculation needed
    output = model.generate(**inputs)
caption = processor.decode(output[0], skip_special_tokens=True)

print("🖼️ Generated Caption:", caption)
# Out:
# C:\Users\ACER\OneDrive\Desktop\SmartCaption\myenv310\lib\site-packages\transformers\generation\utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 🖼️ Generated Caption: two people in a room with a white wall

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis("off")  # Hide axis
plt.show()
